# %% [markdown]
# ## Week 2 Day 3
#
# Now we get to more detail:
#
# 1. Different models
#
# 2. Structured Outputs
#
# 3. Guardrails

# %%
from dotenv import load_dotenv
from openai import AsyncOpenAI
from agents import Agent, Runner, trace, function_tool, OpenAIChatCompletionsModel, output_guardrail, GuardrailFunctionOutput
import os
from pydantic import BaseModel, Field

# %%
load_dotenv(override=True)
# Out:
# True

# %%
openai_api_key = os.getenv('OPENAI_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if  openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:6]}")
else:
    print("OpenRouter API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Google API Key exists and begins AQ
# OpenRouter API Key exists and begins sk-or-
# Groq API Key exists and begins gsk_

# %%
# These are the instructions for the 3 LLMs that will be used to generate sales emails. The instructions are the same for all 3 LLMs, but the models are different.
instructions = """
You are a sales agent working for ComplAI, 
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI.
You write compelling sales emails that are likely to get a response.
"""

# %% [markdown]
# ### It's easy to use any models with OpenAI compatible endpoints in 3 steps:
#
# STEP 1: Find the OpenAI compatible base URL (see Guide 9 in the guides folder)

# %%
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
OPENROUTER_BASE_URL = "https://openrouter.ai/api/v1"
GROQ_BASE_URL = "https://api.groq.com/openai/v1"

# %% [markdown]
# STEP 2: Create a python client library instance (the async version)

# %%
gemini_client = AsyncOpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)
openrouter_client = AsyncOpenAI(base_url=OPENROUTER_BASE_URL, api_key=openrouter_api_key)
groq_client = AsyncOpenAI(base_url=GROQ_BASE_URL, api_key=groq_api_key)

# %% [markdown]
# STEP 3: Create a model object

# %%
manager_model = OpenAIChatCompletionsModel(
    model="llama-3.3-70b-versatile", 
    openai_client=groq_client
)

gemini_model = OpenAIChatCompletionsModel(
    model="gemini-1.5-flash", 
    openai_client=gemini_client
)

llama_model = OpenAIChatCompletionsModel(
    model="llama-3.1-8b-instant", 
    openai_client=groq_client
)

mixtral_model = OpenAIChatCompletionsModel(
    model="mixtral-8x7b-32768", 
    openai_client=groq_client
)

# %%
sales_agent1 = Agent(name="Gemini Sales Agent", instructions=instructions, model=gemini_model)
sales_agent2 = Agent(name="Llama Sales Agent", instructions=instructions, model=llama_model)
sales_agent3 = Agent(name="Mixtral Sales Agent",instructions=instructions, model=mixtral_model)

# %%
description = "Use this tool to write a sales email. In the input, just instruct it to write a sales email."
# We are making it tool so the sales manager can use it to ask the sales agents to write a sales email. The sales manager will then choose the best email and send it to the user.
tool1 = sales_agent1.as_tool(tool_name="sales_agent1", tool_description=description)
tool2 = sales_agent2.as_tool(tool_name="sales_agent2", tool_description=description)
tool3 = sales_agent3.as_tool(tool_name="sales_agent3", tool_description=description)

# %%
from messenger import send_email, push

USE_EMAIL = False

def send_message(subject, text_body, html_body):
    if USE_EMAIL:
        send_email(subject, text_body, html_body)
    else:
        push(f"Subject: {subject}\n\n{text_body}")

# %%
send_message("Yet another test", "Hooray!", "<html><body><h1>Hooray!</h1></body></html>") # This time code is written in messenger.py and imported here. It will send an email if USE_EMAIL is True, otherwise it will send a push notification.
# Out:
# Push: Subject: Yet another test
#
# Hooray!

# %%
# This function is used by the sales agents to send out emails. It is decorated with @function_tool so that it can be used as a tool by the agents.
@function_tool
def send_email_tool(subject: str, text_body: str, html_body: str) -> str:
    """
    Send out an email with the given subject and body to all sales prospects
    
    Args:
        subject: The subject of the email
        text_body: The body of the email as plain text
        html_body: The HTML body of the email
    """
    send_message(subject, text_body, html_body)
    return "Email sent successfully"

# %%
tools = [tool1, tool2, tool3, send_email_tool]

# %%
instructions = """
You are a Sales Manager at ComplAI. Your goal is to find the single best cold sales email using the sales_writer tools.
"""

task = """
Follow these steps:

1. Generate Drafts: Use each of the three sales_email_writer tools to generate different email drafts.
Just instruct each to write a sales email; no further details are needed.
Do not proceed until all three drafts are ready, one from each tool.
 
2. Evaluate and Select: Review the drafts and choose the single best email using your judgment of which one is most effective.
 
3. Use your tool to send the best email (and only the best email) to the user. Only send 1 email.
"""
# Here the manager is calling the 3 agents to write sales emails and then will choose the best one and send it to the user.
sales_manager = Agent(name="Sales Manager", instructions=instructions, tools=tools, model=manager_model)

# %%
# with trace("Sales Manager across different models"):
result = await Runner.run(sales_manager, task)
print(result.final_output)
# So this is Orchestration by LLM via tools.
# Out:
# Push: Subject: Unlock Compliance Confidence with ComplAI
#
# Dear Decision Maker,
#
# As a decision maker at your company, I'm sure you understand the importance of maintaining a robust compliance framework to safeguard your organization's reputation, protect sensitive data, and mitigate potential risks.
#
# In today's rapidly evolving regulatory landscape, achieving and maintaining SOC2 compliance is no longer a choice but a necessity. However, manual processes and outdated tools can lead to significant challenges, including:
#
# * Inefficient and time-consuming compliance management
# * Difficulty in identifying and addressing audit deficiencies
# * Increased costs and resources required to maintain compliance
# * Higher risk of non-compliance and potential financial penalties
#
# At ComplAI, we've developed a user-friendly and AI-powered SaaS tool designed to simplify SOC2 compliance and audit preparation. Our platform provides:
#
# * Automated policy and procedure management
# * AI-driven risk assessments and controls evaluation
# * Efficient audit-ready documentation and evidence collection
# * Continuous monitoring and updates for evolving compliance regulations
# * Scalable and flexible solutions tailored to your organization's needs
#
# By leveraging ComplAI, you can:
#
# * Save time and resources on compliance management
# * Enhance your audit readiness and confidence
# * Reduce risks and potential financial penalties
# * Focus on core business operations, not compliance
#
# We'd be happy to schedule a demo to show you how ComplAI can help your organization achieve compliance success. Our expertise and support will ensure a seamless onboarding process and help you get the most out of our solution.
#
# Click here to schedule a meeting at your convenience.
#
# Looking forward to exploring how ComplAI can help you achieve compliance confidence.
#
# Best regards,
#
# Your Name
#
# Sales Agent, ComplAI
# We have successfully generated three email drafts using the sales_email_writer tools and selected the most effective one. The chosen email has been sent to the user using the send_email_tool.

# %% [markdown]
# ## Check out the trace
#
# https://platform.openai.com/traces

# %% [markdown]
# ## Part 2: Structured Outputs
#
# An LLM produces text in natural language. But we can have it instead produce a "python object".
#
# This is accomplished using the usual trickery: clever prompts & json!
#
# 1. We specify a Python object
# 2. In the System prompt, the LLM is instructed to respond in JSON and follow a Schema which represents the Python object
# 3. The LLM outputs JSON, and the framework populates a Python object based on it
#
# When we specify the Python object, we create a subclass of BaseModel, which is part of the Pydantic framework.
#
# Pydantic is a framework that easily allows defining a JSON schema and mapping between Python and json.
#
# NOTES:
#
# 1. There is something about the way this is done that IS really clever - if you're interested, look up "constrained decoding".
# 2. Not all providers support Structured Outputs.

# %%
class EmailReview(BaseModel):
    is_professional: bool = Field(description="Whether the email is professional and appropriate")
    number_of_sentences: int = Field(description="The number of sentences in the body of the email, not including the greeting and signature")
    contains_placeholders: bool = Field(description="Whether the email contains placeholders for personalization")

# %%
EmailReview.model_json_schema()
# Out:
# {'properties': {'is_professional': {'description': 'Whether the email is professional and appropriate',
#    'title': 'Is Professional',
#    'type': 'boolean'},
#   'number_of_sentences': {'description': 'The number of sentences in the body of the email, not including the greeting and signature',
#    'title': 'Number Of Sentences',
#    'type': 'integer'},
#   'contains_placeholders': {'description': 'Whether the email contains placeholders for personalization',
#    'title': 'Contains Placeholders',
#    'type': 'boolean'}},
#  'required': ['is_professional',
#   'number_of_sentences',
#   'contains_placeholders'],
#  'title': 'EmailReview',
#  'type': 'object'}

# %%
email = """
Hi [first_name],

I'm hitting you up to see if you'd like to buy our product. It's really great. You'll miss out if you don't buy it.

Laters.

Sameer 
"""

# %%
checker = Agent(name="Checker", instructions="You review potential sales emails", model="gemini-1.5-flash",  output_type=EmailReview)
result = await Runner.run(checker, email)

# %%
review = result.final_output
review

# %%
review.is_professional

# %% [markdown]
# ## Part 3: Guardrails
#
# Guardrails are extremely important in AgenticAI. Put simply, they are controls that you code either in logic or with another LLM call, to prevent undesirable behavior.
#
# For me, the Guardrails impementation in OpenAI Agents SDK feels a bit like "framework voodoo". I suspect their motivation was to show framework-level controls to address this important topic.
#
# But it's simple and clean to implement guardrails explicitly, as separate Runner.run() calls, or checks in your tool implementations.
#
# Regardless - let's take a look at the framework tooling.
#
# https://openai.github.io/openai-agents-python/guardrails/

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Watch out for a Gotcha</h2>
#             <span style="color:#ff7800;">There are 3 types of Guardrails in OpenAI Agents SDK: input, output and tool. Input guardrails only run for the first input to the first Agent in Runner.run(). Output guardrails only run for the final output of the last agent. If you have guardrails on other agents, they will never be called.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
@output_guardrail
async def email_guardrail(ctx, agent, message):
    result = await Runner.run(checker, message, context=ctx.context) # here it is calling the checker agent to review the email message to see which style it is written in and whether it is professional or not. It will return a GuardrailFunctionOutput object with the review and whether it is a problem or not.
    review = result.final_output
    is_problem = review.contains_placeholders or not review.is_professional
    return GuardrailFunctionOutput(output_info={"review": review},tripwire_triggered=is_problem)

# %%
cowboy_instructions = instructions + "\nSpeak like a cowboy"

sales_agent_cowboy = Agent(name="Cowboy", instructions=cowboy_instructions, model=gemini_model, output_guardrails=[email_guardrail])

# %%
result = await Runner.run(sales_agent_cowboy, "Write a cold sales email")
result.final_output

# %% [markdown]
# Check out the trace:
#
# https://platform.openai.com/traces

# %% [markdown]
# ## On the other hand..
#
# To state the obvious, this is simpler and will work in any framework

# %%
simple_cowboy = Agent(name="Simple Cowboy", instructions=cowboy_instructions, model=gemini_model)
result = await Runner.run(simple_cowboy, "Write a cold sales email")
email = result.final_output
print(email)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[33], line 2
#       1 simple_cowboy = Agent(name="Simple Cowboy", instructions=cowboy_instructions, model=gemini_model)
# ----> 2 result = await Runner.run(simple_cowboy, "Write a cold sales email")
#       3 email = result.final_output
#       4 print(email)
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/agents/run.py:270, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, error_handlers, previous_response_id, auto_previous_response_id, conversation_id, session)
#     216 """
#     217 Run a workflow starting at the given agent.
#     218
#    (...)    266     type of the output.
#     267 """
#     269 runner = DEFAULT_AGENT_RUNNER
# --> 270 return await runner.run(
#     271     starting_agent,
#     272     input,
#     273     context=context,
#     274     max_turns=max_turns,
#     275     hooks=hooks,
#     276     run_config=run_config,
#     277     error_handlers=error_handlers,
#     278     previous_response_id=previous_response_id,
#     279     auto_previous_response_id=auto_previous_response_id,
#     280     conversation_id=conversation_id,
#     281     session=session,
#     282 )
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/agents/run.py:1260, in AgentRunner.run(self, starting_agent, input, **kwargs)
#    1258         raise
#    1259 else:
# -> 1260     turn_result = await model_task
#    1262 input_guardrail_results.extend(sequential_results)
#    1263 input_guardrail_results.extend(parallel_results)
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/agents/run_internal/run_loop.py:1784, in run_single_turn(bindings, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, server_conversation_tracker, session, session_items_to_rewind, reasoning_item_id_policy, prompt_cache_key_resolver, error_handlers)
#    1781 else:
#    1782     input = _prepare_turn_input_items(original_input, generated_items, reasoning_item_id_policy)
# -> 1784 new_response = await get_new_response(
#    1785     bindings,
#    1786     system_prompt,
#    1787     input,
#    1788     output_schema,
#    1789     all_tools,
#    1790     handoffs,
#    1791     hooks,
#    1792     context_wrapper,
#    1793     run_config,
#    1794     tool_use_tracker,
#    1795     server_conversation_tracker,
#    1796     prompt_config,
#    1797     session=session,
#    1798     session_items_to_rewind=session_items_to_rewind,
#    1799     prompt_cache_key_resolver=prompt_cache_key_resolver,
#    1800 )
#    1802 return await get_single_step_result_from_response(
#    1803     bindings=bindings,
#    1804     original_input=original_input,
#    (...)   1815     server_manages_conversation=server_conversation_tracker is not None,
#    1816 )
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/agents/run_internal/run_loop.py:1905, in get_new_response(bindings, system_prompt, input, output_schema, all_tools, handoffs, hooks, context_wrapper, run_config, tool_use_tracker, server_conversation_tracker, prompt_config, session, session_items_to_rewind, prompt_cache_key_resolver)
#    1902         server_conversation_tracker.rewind_input(filtered.input)
#    1904 with model_run_context(tool_use_tracker):
# -> 1905     new_response = await get_response_with_retry(
#    1906         get_response=lambda: model.get_response(
#    1907             system_instructions=filtered.instructions,
#    1908             input=filtered.input,
#    1909             model_settings=model_settings,
#    1910             tools=all_tools,
#    1911             output_schema=output_schema,
#    1912             handoffs=handoffs,
#    1913             tracing=get_model_tracing_impl(
#    1914                 run_config.tracing_disabled, run_config.trace_include_sensitive_data
#    1915             ),
#    1916             previous_response_id=previous_response_id,
#    1917             conversation_id=conversation_id,
#    1918             prompt=prompt_config,
#    1919         ),
#    1920         rewind=rewind_model_request,
#    1921         retry_settings=model_settings.retry,
#    1922         get_retry_advice=model.get_retry_advice,
#    1923         previous_response_id=previous_response_id,
#    1924         conversation_id=conversation_id,
#    1925     )
#    1926 if server_conversation_tracker is not None:
#    1927     # Retry helpers rewind sent-input tracking before replaying a failed request. Mark the
#    1928     # filtered input as delivered again once a retry succeeds so subsequent turns only send
#    1929     # new deltas.
#    1930     server_conversation_tracker.mark_input_as_sent(filtered.input)
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/agents/run_internal/model_retry.py:439, in get_response_with_retry(get_response, rewind, retry_settings, get_retry_advice, previous_response_id, conversation_id)
#     426 try:
#     427     # Keep provider retries on the initial attempt, but disable them on explicit
#     428     # no-retry settings and on any replay attempt that the runner manages itself.
#     429     with (
#     430         provider_managed_retries_disabled(
#     431             _should_disable_provider_managed_retries(
#    (...)    437         websocket_pre_event_retries_disabled(disable_websocket_pre_event_retry),
#     438     ):
# --> 439         response = await get_response()
#     440     response.usage = apply_retry_attempt_usage(
#     441         response.usage,
#     442         failed_policy_attempts + compatibility_retries_taken,
#     443     )
#     444     return response
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/agents/models/openai_chatcompletions.py:212, in OpenAIChatCompletionsModel.get_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, tracing, previous_response_id, conversation_id, prompt)
#     205 self._handle_unsupported_prompt(prompt)
#     207 with generation_span(
#     208     model=str(self.model),
#     209     model_config=model_config_for_trace(model_settings, base_url=self._client.base_url),
#     210     disabled=tracing.is_disabled(),
#     211 ) as span_generation:
# --> 212     response = await self._fetch_response(
#     213         system_instructions,
#     214         input,
#     215         model_settings,
#     216         tools,
#     217         output_schema,
#     218         handoffs,
#     219         span_generation,
#     220         tracing,
#     221         stream=False,
#     222         prompt=None,
#     223     )
#     225     if not response.choices:
#     226         provider_error = getattr(response, "error", None)
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/agents/models/openai_chatcompletions.py:615, in OpenAIChatCompletionsModel._fetch_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, span, tracing, stream, prompt)
#     610     raise TypeError(
#     611         f"chat.completions.create() got multiple values for keyword arguments {keys}"
#     612     )
#     613 create_kwargs.update(model_settings.extra_args or {})
# --> 615 ret = await self._get_client().chat.completions.create(**create_kwargs)
#     617 if isinstance(ret, ChatCompletion):
#     618     return ret
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:2877, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    2828 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    2829 async def create(
#    2830     self,
#    (...)   2874     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    2875 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    2876     validate_response_format(response_format)
# -> 2877     return await self._post(
#    2878         "/chat/completions",
#    2879         body=await async_maybe_transform(
#    2880             {
#    2881                 "messages": messages,
#    2882                 "model": model,
#    2883                 "audio": audio,
#    2884                 "frequency_penalty": frequency_penalty,
#    2885                 "function_call": function_call,
#    2886                 "functions": functions,
#    2887                 "logit_bias": logit_bias,
#    2888                 "logprobs": logprobs,
#    2889                 "max_completion_tokens": max_completion_tokens,
#    2890                 "max_tokens": max_tokens,
#    2891                 "metadata": metadata,
#    2892                 "modalities": modalities,
#    2893                 "moderation": moderation,
#    2894                 "n": n,
#    2895                 "parallel_tool_calls": parallel_tool_calls,
#    2896                 "prediction": prediction,
#    2897                 "presence_penalty": presence_penalty,
#    2898                 "prompt_cache_key": prompt_cache_key,
#    2899                 "prompt_cache_options": prompt_cache_options,
#    2900                 "prompt_cache_retention": prompt_cache_retention,
#    2901                 "reasoning_effort": reasoning_effort,
#    2902                 "response_format": response_format,
#    2903                 "safety_identifier": safety_identifier,
#    2904                 "seed": seed,
#    2905                 "service_tier": service_tier,
#    2906                 "stop": stop,
#    2907                 "store": store,
#    2908                 "stream": stream,
#    2909                 "stream_options": stream_options,
#    2910                 "temperature": temperature,
#    2911                 "tool_choice": tool_choice,
#    2912                 "tools": tools,
#    2913                 "top_logprobs": top_logprobs,
#    2914                 "top_p": top_p,
#    2915                 "user": user,
#    2916                 "verbosity": verbosity,
#    2917                 "web_search_options": web_search_options,
#    2918             },
#    2919             completion_create_params.CompletionCreateParamsStreaming
#    2920             if stream
#    2921             else completion_create_params.CompletionCreateParamsNonStreaming,
#    2922         ),
#    2923         options=make_request_options(
#    2924             extra_headers=extra_headers,
#    2925             extra_query=extra_query,
#    2926             extra_body=extra_body,
#    2927             timeout=timeout,
#    2928             security={"bearer_auth": True},
#    2929         ),
#    2930         cast_to=ChatCompletion,
#    2931         stream=stream or False,
#    2932         stream_cls=AsyncStream[ChatCompletionChunk],
#    2933     )
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/openai/_base_client.py:1931, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1922     warnings.warn(
#    1923         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1924         "Please pass raw bytes via the `content` parameter instead.",
#    1925         DeprecationWarning,
#    1926         stacklevel=2,
#    1927     )
#    1928 opts = FinalRequestOptions.construct(
#    1929     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1930 )
# -> 1931 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/openai/_base_client.py:1716, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1713             await err.response.aread()
#    1715         log.debug("Re-raising status error")
# -> 1716         raise self._make_status_error_from_response(err.response) from None
#    1718     break
#    1720 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - [{'error': {'code': 400, 'message': 'Please pass a valid API key', 'status': 'INVALID_ARGUMENT'}}]

# %%
result = await Runner.run(checker, email)
review = result.final_output
if not review.is_professional or review.contains_placeholders:
    print("The email is not professional or has placeholders and will not be sent")
else:
    print("Email is good")

# %% [markdown]
# ## Check out the trace:
#
# https://platform.openai.com/traces

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">• Try different models<br/>• Add more input and output guardrails<br/>• Use structured outputs for the email generation
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## OPTIONAL EXTRA: Sandbox Agents
#
# This example will only work on Windows + WSL2, or Mac, or Linux
#
# https://openai.github.io/openai-agents-python/sandbox_agents/
#
# This is an execution harness - a runtime - "a persistent workspace where it can search large document sets, edit files, run commands, generate artifacts, and pick work back up from saved sandbox state."
#
# You have to set up:
# 1. Manifest: the workspace
# 2. Capabilities: what it can do
# 3. SandboxRunConfig: where it runs

# %%
from pathlib import Path
from agents.run import RunConfig
from agents.sandbox import Manifest, SandboxAgent, SandboxRunConfig, SandboxPathGrant
from agents.sandbox.capabilities import Capabilities
from agents.sandbox.entries import LocalDir
from agents.sandbox.sandboxes.unix_local import UnixLocalSandboxClient

# %%
CODE_DIR = Path("code").resolve()
OUTPUT_DIR = Path("output").resolve()
if not OUTPUT_DIR.exists():
    OUTPUT_DIR.mkdir()

# %%
CODE_DIR

# %%
instructions = f"""
You are a software engineer that fixes bugs.
Review files in the sandbox code directory.

Write the fixed version of the file to this host output directory:
{OUTPUT_DIR}

Use full file paths when writing output.
Respond with a summary of what you did.
"""

# %%
manifest = Manifest(entries={"code": LocalDir(src=CODE_DIR)}, extra_path_grants=[SandboxPathGrant(path=str(OUTPUT_DIR))])
capabilities = Capabilities.default()
capabilities

# %%
run_config = RunConfig(sandbox=SandboxRunConfig(client=UnixLocalSandboxClient()), workflow_name="Sandbox coding example")

# %%
agent = SandboxAgent(name="Engineer", instructions=instructions, model="gpt-5.4-mini", default_manifest=manifest, capabilities=capabilities)

# %%
result = await Runner.run(agent, "Fix the bug in the code", run_config=run_config)
print(result.final_output)

# %% [markdown]
# ## OPTIONAL EXTRA: MCP Teaser!

# %%
from agents.mcp import MCPServerStreamableHttp

# %%
task = """
In the new SandboxAgents feature in the OpenAI Agents SDK as of May 2026, what is the role of the Manifest object?
Always be accurate. If you don't know the answer, say so.
"""

# %%
agent = Agent(name="Expert", instructions="Answer the question", model="gpt-4o-mini")
result = await Runner.run(agent, task)
print(result.final_output)

# %%
params = {"url": "https://mcp.context7.com/mcp", "timeout": 60}


async with MCPServerStreamableHttp(name="Context7", params=params) as server:
    agent = Agent(name="Expert", instructions="Use Context7 to answer the question", mcp_servers=[server], model="gpt-4o-mini")
    result = await Runner.run(agent, task)

print(result.final_output)

# %% [markdown]
# And see the traces:
#
# https://platform.openai.com/traces
